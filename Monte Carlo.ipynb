# %%
import numpy as np
import gym

from collections import defaultdict

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
env = gym.make("Blackjack-v0")

# %% [raw]
# Blackjack是一种21点游戏，玩家的目的是使自己的牌面点数之和尽量接近21，但不能超过。
# 根据当前拥有的牌面点数，玩家的动作有两种：hit, stand；
# hit则再获得一张牌，点数超过21时直接失败；
# stand则和庄家点数比较，若点数位于（庄家点数和，21）的区间时则胜利，点数相同平局。
# 庄家只有两张牌，一张展示一张倒扣，不会再获得新牌。
# J、Q、K的点数都当做10；
# Ace的点数可以是1或者11，称作Usable Ace.

# %%
env.observation_space
# Out:
# Tuple(Discrete(32), Discrete(11), Discrete(2))

# %%
env.action_space
# Out:
# Discrete(2)

# %%
observation = env.reset()
observation
# Out:
# (13, 3, False)

# %% [raw]
# observation的3个值分别代表 player_score, dealer_score, usable_ace.
# action的2个值分别代表 stand, hit.
# reward: 胜利1，平局0，失败-1

# %% [markdown]
# ## Prediction

# %% [raw]
# 给定策略，通过多次实验，使用回报和G的平均值估计V(s).
# 本例使用first_visit.

# %%
def generate_episode(policy, env):
    states, actions, rewards = [], [], []
    observation = env.reset()
    
    while True:
        states.append(observation)
        
        action = policy(observation)
        observation, reward, done, _ = env.step(action)
        
        actions.append(action)
        rewards.append(reward)
        
        if done:
            break
            
    return states, actions, rewards

# %%
def first_visit_mc_prediction(policy, env, n_episodes):
    value_table = defaultdict(float)
    N = defaultdict(int)
    
    for _ in range(n_episodes):
        states, actions, rewards = generate_episode(policy, env)
        returns = 0
        for t in range(len(states)-1, -1, -1):
            s = states[t]
            r = rewards[t]
            returns += r
            
            if s not in states[:t]: # first-visit state s
                N[s] += 1
                value_table[s] += (returns - value_table[s]) / N[s] # Incremental
    
    return value_table

# %% [raw]
# 1. V = sum(G)/N，由于之前episode的回报G没有全部记录，使用平均值V来推算，故 V = sum(G)/N = ((N-1)*V + R) / N = V + (R-V)/N
# 2. gamma=1，每个状态s的回报之和returns等于其后所有回报r的加和，故从后向前迭代range(len(states)-1, -1, -1)
# 3. defaultdict，当key值不存在时默认添加，不会像dict那样报错

# %%
def sample_policy(observation):
    score, dealer_score, usable_ace = observation
    
    if score >= 20:
        return 0
    else:
        return 1

# %%
value = first_visit_mc_prediction(sample_policy, env, 500000)

# %% [markdown]
# #### 图示

# %%
def plot_blackjack(V, ax1, ax2):
    player_sum = np.arange(12, 21 + 1)
    dealer_show = np.arange(1, 10 + 1)
    usable_ace = np.array([False, True])

    state_values = np.zeros((len(player_sum),
                                len(dealer_show),
                                len(usable_ace)))

    for i, player in enumerate(player_sum):
        for j, dealer in enumerate(dealer_show):
            for k, ace in enumerate(usable_ace):
                state_values[i, j, k] = V[player, dealer, ace]

    X, Y = np.meshgrid(dealer_show, player_sum) # Y, X

    ax1.plot_wireframe(X, Y, state_values[:, :, 0])
    ax2.plot_wireframe(X, Y, state_values[:, :, 1])
    for ax in ax1, ax2:
        ax.set_zlim(-1, 1)
        ax.set_ylabel('player sum')
        ax.set_xlabel('dealer showing')
        ax.set_zlabel('state-value')

# %%
fig, axes = plt.subplots(nrows=2, figsize=(9, 12), subplot_kw={'projection': '3d'})
axes[0].set_title('value function without usable ace')
axes[1].set_title('value function with usable ace')
plot_blackjack(value, axes[0], axes[1])

# %% [markdown]
# ## Control
