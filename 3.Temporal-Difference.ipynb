# %% [raw]
# 本例实现TD(0)的SARSA和Q-Learning算法。
# gym环境使用Taxi.

# %%
import gym
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
env = gym.make("Taxi-v2")
env.reset()
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
env.action_space.n
# Out:
# 6

# %%
env.step(1)
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)

# %% [raw]
# 图中共有4个位置，RGBY，乘客的出发点和目的地在这四个位置中随机出现，蓝色代表出发点，紫色代表目的地；
# 竖线代表墙，不能通过；冒号代表可通过的区域。
# 黄色方块代表出租车所在位置，当搭载乘客后出租车会变成绿色；
# 出租车有6个动作：上、下、左、右、搭载乘客、放下乘客。
# 每成功放下一名乘客，得到回报20；每走一步回报-1.

# %% [markdown]
# ## TD-Control

# %% [raw]
# 由于model free不知道转移概率P，TD同MC一样需要重复实验，即env.step();
# 实验中要保证能探索到所有的(s,a)，所以仍然需要epsilon-greedy策略来指定每一步采取的动作。
# 本质上仍是搜索所有的(s,a)空间，没有启发和推断。

# %% [raw]
# 但是TD利用了马尔科夫性质，不需要等待实验的episode结束，不需要累加回报G=sum(R)，每一步都在更新q(s,a)的估计值。
# 更新时 q(s,a) = q(s,a) + alpha * (r + gamma * Q - q(s,a))
# 对SARSA: Q = q(s', a') 对应当前策略在下一个状态选择的动作a'，需要策略，on policy;
# 对Q-Learning: Q = max q(s',a) 在下一个状态选择回报最大的动作a，不需要策略指定，off policy.

# %% [raw]
# 当q(s',a') = max q(s',a)时，两种方法的更新过程相同；
# 也就是epsilon-greedy在epsilon越小时，s'选择回报最大的action的几率越高，两种方法越接近；
# 但是epsilon较大时，两种方法对q(s,a)的估计可能有较大的差别，比如cliff问题，Q-Learning只取最大值会忽略周围的危险，而SARSA使用的q(s',a')因为有几率取到危险区域(-100)，更新过程中得到的q(s,a)要明显低于Q-Learning.

# %% [markdown]
# ## Q-Learning

# %%
alpha = 0.4
gamma = 0.9
epsilon = 0.02
episodes = 5000

Q = np.zeros((env.observation_space.n, env.action_space.n))
total_rewards = np.zeros(episodes)

# %%
def epsilon_greedy_policy(state, epsilon):
    if random.uniform(0,1) < epsilon:
        return env.action_space.sample()
    else:
        return max(list(range(env.action_space.n)), key = lambda x: Q[state][x])

# %%
for i in range(episodes):
    state = env.reset()
    
    while True:
        action = epsilon_greedy_policy(state, epsilon)
        state_next, reward, done, _ = env.step(action)
        
        q_max = max([ Q[state_next][a] for a in range(env.action_space.n) ])
        Q[state][action] += alpha * (reward + gamma * q_max - Q[state][action])
        
        state = state_next
        total_rewards[i] += reward
        
        if done:
            break
            
    if i % 1000 == 0:
            print("{} episodes done.".format(i))
# Out:
# 0 episodes done.
# 1000 episodes done.
# 2000 episodes done.
# 3000 episodes done.
# 4000 episodes done.

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(episodes), total_rewards)

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(4000, episodes), total_rewards[4000:])

# %% [markdown]
# ## SARSA

# %%
alpha = 0.4
gamma = 0.9
epsilon = 0.05
episodes = 5000

Q = np.zeros((env.observation_space.n, env.action_space.n))
total_rewards = np.zeros(episodes)

# %%
for i in range(episodes):
    state = env.reset()
    action = epsilon_greedy_policy(state, epsilon)
    
    while True:
        state_next, reward, done, _ = env.step(action)
        action_next = epsilon_greedy_policy(state_next, epsilon)
        
        Q[state][action] += alpha*(reward + gamma*Q[state_next][action_next] - Q[state][action])
        
        state = state_next
        action = action_next
        total_rewards[i] += reward
        
        if done:
            break
    
    if i%1000 == 0:
        print("{} episodes done.".format(i))
# Out:
# 0 episodes done.
# 1000 episodes done.
# 2000 episodes done.
# 3000 episodes done.
# 4000 episodes done.

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(episodes), total_rewards)

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(4000, episodes), total_rewards[4000:])

# %% [raw]
# epsilon参数值设置越大，越容易选择非最优策略，出现得分较低的情况。

# %%
env.close()
